# %% [markdown]
# # Make new data based on experimental data

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X = pd.read_csv('preprocessed_data/X.csv')
y = pd.read_csv('preprocessed_data/target.csv')
data = pd.read_csv('preprocessed_data/data.csv')

data
# Out:
#     Compound  Perovskite  Cubic     rA     rB  MA  MB    dAO    dBO  rA/rO  \
# 0     AgBiO3          -1      0  1.460  0.760  65  86  1.805  2.060  1.081
# 1     AgBrO3          -1      0  1.460  0.470  65  95  1.805  1.840  1.081
# 2      AgNO3          -1      0  1.460  0.130  65  82  1.805  1.432  1.081
# 3      AgPO3          -1      0  1.460  0.380  65  83  1.805  1.604  1.081
# 4     AgSbO3          -1      0  1.460  0.600  65  85  1.805  1.942  1.081
# ..       ...         ...    ...    ...    ...  ..  ..    ...    ...    ...
# 385    YMnO3           1     -1  1.196  0.645  12  52  2.014  1.732  0.886
# 386    YNiO3           1     -1  1.196  0.600  12  61  2.014  1.750  0.886
# 387    YScO3           1     -1  1.196  0.745  12  11  2.014  1.849  0.886
# 388    YTiO3           1     -1  1.196  0.670  12  43  2.014  1.791  0.886
# 389     YVO3           1     -1  1.196  0.640  12  46  2.014  1.749  0.886
#
#      rB/rO      t
# 0    0.563  0.942
# 1    0.348  1.092
# 2    0.096  1.343
# 3    0.281  1.149
# 4    0.444  1.019
# ..     ...    ...
# 385  0.478  0.902
# 386  0.444  0.923
# 387  0.552  0.859
# 388  0.496  0.891
# 389  0.474  0.905
#
# [390 rows x 12 columns]

# %%
unique_A_atoms = X["MA", "rA"]
unique_A_atoms = list(set(unique_A_atoms.to_list()))
print(len(unique_A_atoms))


unique_B_atoms = X.MB
unique_B_atoms = list(set(unique_B_atoms.to_list()))
print(len(unique_B_atoms))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('MA', 'rA')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-d27b06985ede> in <module>
# ----> 1 unique_A_atoms = X["MA", "rA"]
#       2 unique_A_atoms = list(set(unique_A_atoms.to_list()))
#       3 print(len(unique_A_atoms))
#       4
#       5
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: ('MA', 'rA')
