# %% [markdown]
# # Preprocessing
#
# In this Jupyter notebook we will investigate how the data from dataMining.ipynb looks like, and try to understand how it is put together.

# %%
import os
if not os.path.exists('data/preprocessing'):
    os.makedirs('data/preprocessing')

# Tools for query of data
#from pymatgen 

from matminer.featurizers.composition import ElementFraction
from pymatgen import Composition

# Load featurizers and conversion functions
from matminer.featurizers.composition import ElementProperty, OxidationStates
from matminer.featurizers.structure import DensityFeatures
from matminer.featurizers.dos import DOSFeaturizer
from matminer.featurizers.conversions import CompositionToOxidComposition, StrToComposition

# pandas
import pandas as pd
import numpy as np

from tqdm import tqdm

# plotting 
import plotly.graph_objects as go

# Ignore warnings from nan-values in  
np.warnings.filterwarnings('ignore')

# %%
from helperFunctions import read_csv
data = read_csv("data/stage_4/MP_data_stage_4.csv")
data
# Out:
#      material_id full_formula                                  icsd_ids  \
# 0        mp-1000       Ba1Te1            [616165, 616163, 29152, 43656]
# 1     mp-1006878        Ba1O2                                  [180398]
# 2       mp-10074       Ge2Se4                    [50761, 637859, 90957]
# 3     mp-1008500        Ba2O2                                  [173921]
# 4     mp-1008680    Ti1Ge1Pt1                          [188964, 188965]
# ...          ...          ...                                       ...
# 1061   mp-984729     Ba1Sr3O4                                  [180202]
# 1062   mp-985829        Hf1S2  [638851, 601164, 603757, 182677, 638847]
# 1063   mp-985831       Hf1Se2  [195308, 638902, 182678, 638899, 603743]
# 1064     mp-9921        Zr2S6                   [42073, 651463, 651485]
# 1065     mp-9922        Hf2S6                           [638846, 42074]
#
#       spacegroup.number  band_gap run_type  \
# 0                   225    1.8555      GGA
# 1                    65    2.3433      GGA
# 2                   122    1.6631      GGA
# 3                   194    2.4251      GGA
# 4                   216    0.9376      GGA
# ...                 ...       ...      ...
# 1061                221    2.5199      GGA
# 1062                164    1.2325      GGA
# 1063                164    0.5549      GGA
# 1064                 11    1.0948      GGA
# 1065                 11    1.1361      GGA
#
#                                                     cif  e_above_hull  \
# 0     # generated using pymatgen\ndata_BaTe\n_symmet...      0.000000
# 1     # generated using pymatgen\ndata_BaO2\n_symmet...      0.120015
# 2     # generated using pymatgen\ndata_GeSe2\n_symme...      0.000000
# 3     # generated using pymatgen\ndata_BaO\n_symmetr...      0.025751
# 4     # generated using pymatgen\ndata_TiGePt\n_symm...      0.000000
# ...                                                 ...           ...
# 1061  # generated using pymatgen\ndata_BaSr3O4\n_sym...      0.044250
# 1062  # generated using pymatgen\ndata_HfS2\n_symmet...      0.000000
# 1063  # generated using pymatgen\ndata_HfSe2\n_symme...      0.000000
# 1064  # generated using pymatgen\ndata_ZrS3\n_symmet...      0.000000
# 1065  # generated using pymatgen\ndata_HfS3\n_symmet...      0.000000
#
#                 elements                                 dos  \
# 0           ['Ba', 'Te']  {'GGA': {'task_id': 'mp-1686464'}}
# 1            ['Ba', 'O']  {'GGA': {'task_id': 'mp-1667967'}}
# 2           ['Ge', 'Se']  {'GGA': {'task_id': 'mp-1701570'}}
# 3            ['Ba', 'O']  {'GGA': {'task_id': 'mp-1695159'}}
# 4     ['Ti', 'Ge', 'Pt']  {'GGA': {'task_id': 'mp-1687503'}}
# ...                  ...                                 ...
# 1061   ['Ba', 'Sr', 'O']  {'GGA': {'task_id': 'mp-1730558'}}
# 1062         ['Hf', 'S']  {'GGA': {'task_id': 'mp-1686545'}}
# 1063        ['Hf', 'Se']  {'GGA': {'task_id': 'mp-1686558'}}
# 1064         ['Zr', 'S']  {'GGA': {'task_id': 'mp-1697936'}}
# 1065         ['Hf', 'S']  {'GGA': {'task_id': 'mp-1700641'}}
#
#                                               structure  col_id
# 0     Full Formula (Ba1 Te1)\nReduced Formula: BaTe\...     NaN
# 1     Full Formula (Ba1 O2)\nReduced Formula: BaO2\n...     NaN
# 2     Full Formula (Ge2 Se4)\nReduced Formula: GeSe2...     NaN
# 3     Full Formula (Ba2 O2)\nReduced Formula: BaO\na...     NaN
# 4     Full Formula (Ti1 Ge1 Pt1)\nReduced Formula: T...     NaN
# ...                                                 ...     ...
# 1061  Full Formula (Ba1 Sr3 O4)\nReduced Formula: Ba...     NaN
# 1062  Full Formula (Hf1 S2)\nReduced Formula: HfS2\n...     NaN
# 1063  Full Formula (Hf1 Se2)\nReduced Formula: HfSe2...     NaN
# 1064  Full Formula (Zr2 S6)\nReduced Formula: ZrS3\n...     NaN
# 1065  Full Formula (Hf2 S6)\nReduced Formula: HfS3\n...     NaN
#
# [1066 rows x 12 columns]

# %%
data.describe()
# Out:
#        spacegroup.number     band_gap  e_above_hull  col_id
# count        1066.000000  1066.000000   1066.000000     0.0
# mean           88.555347     3.044849      0.030098     NaN
# std            74.382284     1.522290      0.048863     NaN
# min             2.000000     0.507200      0.000000     NaN
# 25%            15.000000     1.856100      0.000000     NaN
# 50%            62.000000     2.903250      0.008320     NaN
# 75%           148.000000     4.137400      0.036963     NaN
# max           230.000000     6.790700      0.199990     NaN

# %%
df = StrToComposition().featurize_dataframe(data[["full_formula", "dos", "structure"]], "full_formula")
df = ElementFraction().featurize_dataframe(df, "composition")
df = DOSFeaturizer().featurize_dataframe(df, "dos", ignore_errors=True)
# Out:
# HBox(children=(HTML(value='StrToComposition'), FloatProgress(value=0.0, max=1066.0), HTML(value='')))
# HBox(children=(HTML(value='ElementFraction'), FloatProgress(value=0.0, max=1066.0), HTML(value='')))
# HBox(children=(HTML(value='DOSFeaturizer'), FloatProgress(value=0.0, max=1066.0), HTML(value='')))

# %%
df
# Out:
#      full_formula                                 dos  \
# 0          Ba1Te1  {'GGA': {'task_id': 'mp-1686464'}}
# 1           Ba1O2  {'GGA': {'task_id': 'mp-1667967'}}
# 2          Ge2Se4  {'GGA': {'task_id': 'mp-1701570'}}
# 3           Ba2O2  {'GGA': {'task_id': 'mp-1695159'}}
# 4       Ti1Ge1Pt1  {'GGA': {'task_id': 'mp-1687503'}}
# ...           ...                                 ...
# 1061     Ba1Sr3O4  {'GGA': {'task_id': 'mp-1730558'}}
# 1062        Hf1S2  {'GGA': {'task_id': 'mp-1686545'}}
# 1063       Hf1Se2  {'GGA': {'task_id': 'mp-1686558'}}
# 1064        Zr2S6  {'GGA': {'task_id': 'mp-1697936'}}
# 1065        Hf2S6  {'GGA': {'task_id': 'mp-1700641'}}
#
#                                               structure   composition  H  He  \
# 0     Full Formula (Ba1 Te1)\nReduced Formula: BaTe\...      (Ba, Te)  0   0
# 1     Full Formula (Ba1 O2)\nReduced Formula: BaO2\n...       (Ba, O)  0   0
# 2     Full Formula (Ge2 Se4)\nReduced Formula: GeSe2...      (Ge, Se)  0   0
# 3     Full Formula (Ba2 O2)\nReduced Formula: BaO\na...       (Ba, O)  0   0
# 4     Full Formula (Ti1 Ge1 Pt1)\nReduced Formula: T...  (Ti, Ge, Pt)  0   0
# ...                                                 ...           ... ..  ..
# 1061  Full Formula (Ba1 Sr3 O4)\nReduced Formula: Ba...   (Ba, Sr, O)  0   0
# 1062  Full Formula (Hf1 S2)\nReduced Formula: HfS2\n...       (Hf, S)  0   0
# 1063  Full Formula (Hf1 Se2)\nReduced Formula: HfSe2...      (Hf, Se)  0   0
# 1064  Full Formula (Zr2 S6)\nReduced Formula: ZrS3\n...       (Zr, S)  0   0
# 1065  Full Formula (Hf2 S6)\nReduced Formula: HfS3\n...       (Hf, S)  0   0
#
#       Li  Be  B    C  ...  cbm_hybridization  cbm_character_1  cbm_specie_1  \
# 0      0   0  0  0.0  ...                NaN              NaN           NaN
# 1      0   0  0  0.0  ...                NaN              NaN           NaN
# 2      0   0  0  0.0  ...                NaN              NaN           NaN
# 3      0   0  0  0.0  ...                NaN              NaN           NaN
# 4      0   0  0  0.0  ...                NaN              NaN           NaN
# ...   ..  .. ..  ...  ...                ...              ...           ...
# 1061   0   0  0  0.0  ...                NaN              NaN           NaN
# 1062   0   0  0  0.0  ...                NaN              NaN           NaN
# 1063   0   0  0  0.0  ...                NaN              NaN           NaN
# 1064   0   0  0  0.0  ...                NaN              NaN           NaN
# 1065   0   0  0  0.0  ...                NaN              NaN           NaN
#
#       cbm_location_1  cbm_score_1  vbm_hybridization  vbm_character_1  \
# 0                NaN          NaN                NaN              NaN
# 1                NaN          NaN                NaN              NaN
# 2                NaN          NaN                NaN              NaN
# 3                NaN          NaN                NaN              NaN
# 4                NaN          NaN                NaN              NaN
# ...              ...          ...                ...              ...
# 1061             NaN          NaN                NaN              NaN
# 1062             NaN          NaN                NaN              NaN
# 1063             NaN          NaN                NaN              NaN
# 1064             NaN          NaN                NaN              NaN
# 1065             NaN          NaN                NaN              NaN
#
#       vbm_specie_1  vbm_location_1  vbm_score_1
# 0              NaN             NaN          NaN
# 1              NaN             NaN          NaN
# 2              NaN             NaN          NaN
# 3              NaN             NaN          NaN
# 4              NaN             NaN          NaN
# ...            ...             ...          ...
# 1061           NaN             NaN          NaN
# 1062           NaN             NaN          NaN
# 1063           NaN             NaN          NaN
# 1064           NaN             NaN          NaN
# 1065           NaN             NaN          NaN
#
# [1066 rows x 117 columns]

# %% [markdown]
# ## Featurize with matminer
